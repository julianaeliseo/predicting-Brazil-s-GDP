# %%
#First I'am collecting the indicators for estimating the GDP:

## IPCA
## O IPCA - Índice Nacional de Preços ao Consumidor Amplo - 
## aponta a variação do custo de vida médio de famílias com renda mensal de 1 e 40 salários mínimos.

## Custo do m²
## As séries mensais de custos e índices de custos referem-se ao valor do metro quadrado de uma construção
## no canteiro de obras. São medidas pela SINAPI - Sistema Nacional de Pesquisa de Custos e Índices da Construção Civil.

## PIB real variação anual
##A variação do PIB, medida pelo SCNT - Sistema de Contas Nacionais Trimestrais - traz a evolução do PIB no tempo,
##comparando seu desempenho trimestre a trimestre e ano a ano.

## Indústria
## A produção da indústria é calculada pela PIM-PF - Pesquisa Industrial Mensal Produção Física - 
## e reflete as alterações das quantidades de bens e serviços produzidos pela indústria ao longo do tempo.


## Comércio
## A variação do índice de volume de vendas do comércio varejista é calculada pela PMC - Pesquisa Mensal do Comércio.

## Serviços
## A variação do índice do volume de serviços é calculada pela 
## PMS - Pesquisa Mensal de Serviços e permite acompanhar o comportamento conjuntural deste setor no País.

## Estimativa da população
## As estimativas anuais de população para os municípios e para as Unidades da Federação brasileiras 
## têm data de referência em 1º de julho e são realizadas para os anos em que não há Censo Demográfico ou Contagem da População.

## Desemprego
## O desemprego se refere às pessoas com idade para trabalhar que não estão trabalhando, mas estão disponíveis 
## e tentam encontrar trabalho. É calculado pela PNAD Contínua - Pesquisa Nacional por Amostra de Domicílios Contínua.

# %%
## IPCA data
import pandas as pd

df4 = pd.read_csv("./IPCA.csv", index_col=0)
print(df4)
# Out:
#        IPCA
# year
# 1994  18.57
# 1995  22.41
# 1996   9.56
# 1997   5.22
# 1998   1.65
# 1999   8.94
# 2000   5.97
# 2001   7.67
# 2002  12.53
# 2003   9.30
# 2004   7.60
# 2005   5.69
# 2006   3.14
# 2007   4.46
# 2008   5.90
# 2009   4.31
# 2010   5.91
# 2011   6.50
# 2012   5.84
# 2013   5.91
# 2014   6.41
# 2015  10.67
# 2016   6.29
# 2017   2.95
# 2018   3.75
# 2019   4.31
# 2020   0.21

# %%
df4.dtypes
list_of_df = []
list_of_df.append('df4')

# %%
#Square root meter cost data
df1 = pd.read_excel("./var custo medio m2.xlsx", index_col = 0)
print(df1)
list_of_df.append('df1')
# Out:
#       var custo medio m2
# Year
# 1994                3.96
# 1995               20.25
# 1996                4.83
# 1997                4.16
# 1998                1.57
# 1999                7.62
# 2000                6.01
# 2001                8.60
# 2002               12.68
# 2003               13.47
# 2004               10.44
# 2005                6.77
# 2006                5.03
# 2007                5.93
# 2008               11.18
# 2009                5.70
# 2010                7.11
# 2011                5.51
# 2012                5.53
# 2013                1.17
# 2014                6.03
# 2015                5.37
# 2016                6.45
# 2017                3.76
# 2018                4.32
# 2019                3.96
# 2020                9.74

# %%
#real GDP anual variation
df2 = pd.read_excel("./PIBReal_1947_2018.xls", header = 1)
print(df2)
# Out:
#      Ano         %     Razão     1947=100    1990=100  Unnamed: 5 Unnamed: 6  \
# 0   1947       NaN       NaN   100.000000    7.990484         NaN        NaN
# 1   1948  9.700000  1.097000   109.700000    8.765561         NaN        NaN
# 2   1949  7.700000  1.077000   118.146900    9.440510         NaN        NaN
# 3   1950  6.800000  1.068000   126.180889   10.082464         NaN        NaN
# 4   1951  4.900000  1.049000   132.363753   10.576505         NaN  1960/1951
# ..   ...       ...       ...          ...         ...         ...        ...
# 67  2014  0.503956  1.005040  2549.198005  203.693270         NaN        NaN
# 68  2015 -3.545763  0.964542  2458.809475  196.470788         NaN        NaN
# 69  2016 -3.275917  0.967241  2378.260920  190.034569         NaN        NaN
# 70  2017  1.322869  1.013229  2409.722197  192.548477         NaN        NaN
# 71  2018  1.783667  1.017837  2452.703611  195.982900         NaN        NaN
#
# ...

# %%
df3 = df2.drop(["Razão","1947=100","1990=100","Unnamed: 5","Unnamed: 6","Unnamed: 7","Unnamed: 8"],axis=1)
df3 = df3.rename(columns={"%": "GDP anual var"})
df3 = df3.rename(columns={"Ano": "Year"})
df = df3.drop([0])
df
# Out:
#     Year  GDP anual var
# 1   1948       9.700000
# 2   1949       7.700000
# 3   1950       6.800000
# 4   1951       4.900000
# 5   1952       7.300000
# ..   ...            ...
# 67  2014       0.503956
# 68  2015      -3.545763
# 69  2016      -3.275917
# 70  2017       1.322869
# 71  2018       1.783667
#
# [71 rows x 2 columns]

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
df5=df.set_index('Year')
print(df5)
list_of_df.append('df5')
# Out:
#       GDP anual var
# Year
# 1948       9.700000
# 1949       7.700000
# 1950       6.800000
# 1951       4.900000
# 1952       7.300000
# ...             ...
# 2014       0.503956
# 2015      -3.545763
# 2016      -3.275917
# 2017       1.322869
# 2018       1.783667
#
# [71 rows x 1 columns]

# %%
# Industry
df6 = pd.read_excel("./Industry.xlsx", index_col = 0)
print(df6)
list_of_df.append('df6')
# Out:
#       General Industry  Extraction Industry  Transformation Industry
# Year
# 2002             953.7                801.1                    963.1
# 2003             957.5                840.7                    965.0
# 2004            1034.1                877.1                   1043.5
# 2005            1066.2                965.9                   1073.4
# 2006            1096.6               1038.1                   1099.8
# 2007            1159.4               1099.1                   1162.5
# 2008            1192.6               1141.3                   1194.7
# 2009            1109.7               1038.6                   1112.8
# 2010            1223.5               1179.5                   1226.5
# 2011            1228.7               1204.9                   1231.9
# 2012            1199.1               1199.4                   1197.4
# 2013            1224.8               1155.1                   1232.9
# ...

# %%
#Commerce
df7 = pd.read_excel("./Commerce.xlsx", index_col = 0)
print(df7)

list_of_df.append('df7')
# Out:
#       Sells volume
# Year
# 2000         605.0
# 2001         595.8
# 2002         591.5
# 2003         569.8
# 2004         622.4
# 2005         652.4
# 2006         692.8
# 2007         759.9
# 2008         829.4
# 2009         877.6
# 2010         973.6
# 2011        1038.5
# 2012        1125.8
# 2013        1173.9
# 2014        1200.1
# 2015        1147.9
# 2016        1076.1
# 2017        1098.6
# 2018        1124.0
# 2019        1144.8
# 2020        1033.3

# %%
#Services
df8 = pd.read_excel("./Services.xlsx", index_col = 0)
print(df8)
list_of_df.append('df8')
# Out:
#       Services volume indice
# Year
# 2011                  1078.2
# 2012                  1124.2
# 2013                  1170.1
# 2014                  1200.1
# 2015                  1156.8
# 2016                  1098.6
# 2017                  1067.5
# 2018                  1067.2
# 2019                  1077.7
# 2020                   897.9

# %%
#Population
df9 = pd.read_excel("./Population.xls", index_col = 0)
print(df9)
list_of_df.append('df9')
# Out:
#       population
# year
# 2001   172385826
# 2002   174632960
# 2003   176871437
# 2004   181581024
# 2005   184184264
# 2006   186770562
# 2007   183989711
# 2008   189612814
# 2009   191480630
# 2010   190747855
# 2011   192379287
# 2012   193946886
# 2013   201032714
# 2014   202768562
# 2015   204450649
# 2016   206081432
# 2017   207660929
# 2018   208494900
# 2019   210147125
# 2020   211755692

# %%
#Unemployment

df10 = pd.read_excel("./Unemployment.xlsx", index_col = 0) 
print(df10)
list_of_df.append("df10")
# Out:
#       Vacancy Rate
# Year
# 2012          73.1
# 2013          86.4
# 2014          81.4
# 2015          99.4
# 2016         135.1
# 2017         153.2
# 2018         147.1
# 2019         143.1
# 2020         145.0

# %%
list_of_df
# Out:
# ['df4', 'df1', 'df5', 'df6', 'df7', 'df8', 'df9', 'df10']

# %%
frames = [df5, df1,df4,df6,df7,df8,df9,df10]

result = pd.concat(frames, axis=1).reindex(df5.index)

# %%
pd.set_option("max_rows", None)
result
# Out:
#       GDP anual var  var custo medio m2   IPCA  General Industry  \
# Year
# 1948       9.700000                 NaN    NaN               NaN
# 1949       7.700000                 NaN    NaN               NaN
# 1950       6.800000                 NaN    NaN               NaN
# 1951       4.900000                 NaN    NaN               NaN
# 1952       7.300000                 NaN    NaN               NaN
# 1953       4.700000                 NaN    NaN               NaN
# 1954       7.800000                 NaN    NaN               NaN
# 1955       8.800000                 NaN    NaN               NaN
# 1956       2.900000                 NaN    NaN               NaN
# 1957       7.700000                 NaN    NaN               NaN
# 1958      10.800000                 NaN    NaN               NaN
# 1959       9.800000                 NaN    NaN               NaN
# 1960       9.400000                 NaN    NaN               NaN
# ...

# %%
#filling nan values with sklearn nearest algorithm

from sklearn.impute import KNNImputer
imputer = KNNImputer(n_neighbors=2)
df_filled = imputer.fit_transform(result)
newdf = pd.DataFrame(df_filled)

# %%
newdf.columns = result.columns

# %%
dfindex = df
year = dfindex['Year']
dataframe = newdf.set_index(year)

# %%
dataframe
# Out:
#       GDP anual var  var custo medio m2    IPCA  General Industry  \
# Year
# 1948       9.700000               6.520   5.185           1191.45
# 1949       7.700000               6.520   5.185           1191.45
# 1950       6.800000               8.185   6.030           1096.75
# 1951       4.900000               7.735   5.370           1065.35
# 1952       7.300000               8.185   6.030           1096.75
# 1953       4.700000              11.560  10.065            993.90
# 1954       7.800000               5.535  12.240           1128.80
# 1955       8.800000               8.775   6.755           1128.80
# 1956       2.900000              10.640  10.100            955.60
# 1957       7.700000               6.520   5.185           1191.45
# 1958      10.800000               6.520   5.185           1191.45
# 1959       9.800000               6.520   5.185           1191.45
# 1960       9.400000               8.775   6.755           1128.80
# ...

# %%
#now data has zero nan values

#modeling

from sklearn.linear_model import ElasticNetCV
from sklearn.datasets import make_regression
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
#Separate Features and target

X_Target = dataframe['GDP anual var'] 

feature_df= dataframe.loc[:, dataframe.columns != 'GDP anual var']

#Split the data

X_train, X_test, y_train, y_test = train_test_split(feature_df, X_Target, test_size=0.4,random_state=0)

alphas = [0.0000001, 0.001, 0.01, 0.1, 0.3, 0.5, 0.7, 1]
elastic_cv=ElasticNetCV(alphas=alphas, cv=10, l1_ratio=20, fit_intercept=True, normalize=False, precompute=False, max_iter=1000000,  tol=0.1, random_state=None, selection='cyclic')
model = elastic_cv.fit(X_train, y_train)
ypred = model.predict(X_test)
score = model.score(X_test, y_test)
mse = mean_squared_error(y_test, ypred)
print("R2:{0:.4f}, MSE:{1:.4f}, RMSE:{2:.4f}"
      .format(score, mse, np.sqrt(mse)))
# Out:
# R2:0.5953, MSE:6.5947, RMSE:2.5680

# %%
import matplotlib.pyplot as plt
x_ax = range(len(X_test))
plt.plot(x_ax, y_test, lw=0.5, color="blue", label='original')
plt.plot(x_ax, ypred, lw=0.8, color='red', label='predicted')
plt.legend()
plt.show()

# %%
# these prediciton uses the GDP to predict the GDP

# %%
# now predict the GDP by calculating a new GDP through the indicators 

cdf = pd.read_excel('./completedataframe1995-2020copy.xlsx', header = 2)

# %%
cdf
# Out:
#       Período AGROPECUÁRIA              INDÚSTRIA  \
# 0         NaT        Total  Indústrias extrativas
# 1  1996-03-31      10053.7                 1763.5
# 2  1996-06-25      10702.7                1369.17
# 3  1996-09-25        11096                1323.55
# 4  1996-12-31      8906.17                1457.31
# 5  1997-03-31      12337.9                1492.98
# 6  1997-06-25      11625.1                1446.95
# 7  1997-09-25      10871.3                1424.72
# 8  1997-12-31      9771.46                1655.54
# 9  1998-03-31      11868.8                1383.18
# 10 1998-06-25      14201.7                1122.22
# 11 1998-09-25      13142.7                1354.27
# 12 1998-12-31      8398.88                1632.39
# 13 1999-03-31      14190.2                1560.17
# 14 1999-06-25      13487.3                1562.19
# 15 1999-09-25        11736                2242.77
# 16 1999-12-31      11121.4                2601.46
# 17 2000-03-31      16346.9                2956.38
# ...

# %%
cdf1 = cdf.drop(columns=['AGROPECUÁRIA','INDÚSTRIA','Unnamed: 3','Unnamed: 4','Unnamed: 5','Unnamed: 6','SERVIÇOS','Unnamed: 8','Unnamed: 9','Unnamed: 10','Unnamed: 11','Unnamed: 12','Unnamed: 13','Unnamed: 14','VA','Imposto'])
cdf1
# Out:
#       Período           PIB  Consumo das Famílias  Consumo do Governo  \
# 0         NaT           NaN                   NaN                 NaN
# 1  1996-03-31  1.893233e+05          1.256850e+05        35666.080219
# 2  1996-06-25  2.046107e+05          1.325109e+05        39022.695113
# 3  1996-09-25  2.215132e+05          1.426583e+05        41810.459717
# 4  1996-12-31  2.393163e+05          1.560875e+05        52323.642223
# 5  1997-03-31  2.191170e+05          1.478079e+05        42139.016772
# 6  1997-06-25  2.328895e+05          1.544465e+05        45484.648067
# 7  1997-09-25  2.461785e+05          1.575978e+05        45829.943773
# 8  1997-12-31  2.539041e+05          1.619536e+05        52539.822615
# 9  1998-03-31  2.357007e+05          1.571029e+05        46994.030117
# 10 1998-06-25  2.519359e+05          1.591939e+05        49306.681276
# 11 1998-09-25  2.580433e+05          1.634473e+05        49839.273579
# ...

# %%
cdf2 = cdf1.drop([0])
cdf2
# Out:
#       Período           PIB  Consumo das Famílias  Consumo do Governo  \
# 1  1996-03-31  1.893233e+05          1.256850e+05        35666.080219
# 2  1996-06-25  2.046107e+05          1.325109e+05        39022.695113
# 3  1996-09-25  2.215132e+05          1.426583e+05        41810.459717
# 4  1996-12-31  2.393163e+05          1.560875e+05        52323.642223
# 5  1997-03-31  2.191170e+05          1.478079e+05        42139.016772
# 6  1997-06-25  2.328895e+05          1.544465e+05        45484.648067
# 7  1997-09-25  2.461785e+05          1.575978e+05        45829.943773
# 8  1997-12-31  2.539041e+05          1.619536e+05        52539.822615
# 9  1998-03-31  2.357007e+05          1.571029e+05        46994.030117
# 10 1998-06-25  2.519359e+05          1.591939e+05        49306.681276
# 11 1998-09-25  2.580433e+05          1.634473e+05        49839.273579
# 12 1998-12-31  2.566712e+05          1.631868e+05        55037.192923
# ...

# %%
# THE GDP (PIB) is calculated:
# PIB = CF + CG + FBCF + VE + E - I
# CF = consumo das famílias
# CG = consumo do governo
# FBCF = formação bruta do capital fixo
# VE = variação de estoques
# E = exportação
# I = importação

#So for the GDP value at 1995 there is 7.06e+05 we have:
#Axis 0 will act on all the ROWS in each COLUMN  -  Axis 1 will act on all the COLUMNS in each ROW

GDP_1995 = cdf2.sum(axis=1)
GDP_1995_1 = GDP_1995.values - 2*(cdf2['Importação'].values)  - (cdf2['PIB'].values)
GDP_1995_1[0] = GDP_1995_1[0].round(5)

if GDP_1995_1[0] == cdf2.loc[1,'PIB'].round(5):
    print('math is right')
else:
    print('something is wrong')
# Out:
# math is right

# %%
cdf3 = cdf2.drop(columns=['Período'])

X_Target = cdf3['PIB'] 

feature_df= cdf3.loc[:, cdf3.columns != 'PIB']

#Split the data

X_train, X_test, y_train, y_test = train_test_split(feature_df, X_Target, test_size=0.6,random_state=0)

alphas = [0.00000000000001, 0.0000001,0.00001, 0.001, 0.3, 0.5, 0.7, 1, 2, 3, 4]
elastic_cv=ElasticNetCV(alphas=alphas, cv=4, l1_ratio=20, fit_intercept=True, normalize=False, precompute=False, max_iter=100000000,  tol=0.1, random_state=None, selection='cyclic')
model = elastic_cv.fit(X_train, y_train)
ypred = model.predict(X_test)
score = model.score(X_test, y_test)
mse = mean_squared_error(y_test, ypred)
print("R2:{0:.4f}, MSE:{1:.4f}, RMSE:{2:.4f}"
      .format(score, mse, np.sqrt(mse)))
# Out:
# R2:0.9978, MSE:654838223.7194, RMSE:25589.8070

# %%
import matplotlib.pyplot as plt
x_ax = range(len(X_test))
plt.scatter(x_ax, y_test, lw=0.5, color="blue", label='original')
plt.plot(x_ax, ypred, lw=0.8, color='red', label='predicted')
plt.legend()
plt.show()

print("y_test=%s, ypred=%s" % (y_test[44], ypred[2]))
# Out:
# y_test=655354.894153527, ypred=240172.24214266293

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt

rms = sqrt(mean_squared_error(y_test, ypred))
rms
# Out:
# 25589.807027786883

# %%
ypred
# Out:
# array([ 380722.43491463, 1691862.95293018,  240172.24214266,
#         885633.85841047, 1520743.59275816, 1827850.10018264,
#         292201.78568364, 1417550.40349384,  852471.48574163,
#        1918012.81751895,  805321.95451305, 1850886.2966868 ,
#        1517026.1834464 ,  284472.66093409,  270108.56430133,
#         436440.93139642,  349677.26428262,  355337.19365213,
#         466143.19648287,  258118.76887566,  622925.50711376,
#        1075761.06387267,  258320.2558781 , 1377809.4840041 ,
#         652179.22820094,  709119.53381459,  264332.18874223,
#        1830272.10034174, 1606409.97776676, 1498812.76148622,
#        1007653.63724   , 1539685.61160878, 1740457.81402488,
#        1256439.45311679,  780199.53910777,  391619.01119319,
#         332117.91461504,  882742.7067817 , 1112291.29678123,
#        1459577.12161538,  222126.18070234, 1049949.62173857,
#         596780.1355665 ,  576684.48809526,  244073.23497036,
# ...

# %%
y_test
# Out:
# 27    3.797945e+05
# 87    1.648571e+06
# 3     2.215132e+05
# 56    9.204915e+05
# 76    1.508527e+06
# 93    1.765633e+06
# 17    2.769269e+05
# 74    1.422320e+06
# 55    8.528432e+05
# 95    1.884003e+06
# 54    8.035775e+05
# 92    1.821484e+06
# 79    1.508227e+06
# 14    2.687089e+05
# 8     2.539041e+05
# 31    4.393498e+05
# 23    3.325244e+05
# 25    3.422967e+05
# 34    4.817950e+05
# 9     2.357007e+05
# 44    6.553549e+05
# 63    1.112334e+06
# 4     2.393163e+05
# 72    1.413291e+06
# 46    6.706547e+05
# 49    7.120552e+05
# 7     2.461785e+05
# 99    1.891735e+06
# 83    1.577187e+06
# 77    1.456671e+06
# 61    1.016531e+06
# 81    1.500226e+06
# 90    1.733453e+06
# 69    1.241614e+06
# 52    8.156201e+05
# 28    3.993332e+05
# 19    3.088958e+05
# 57    8.863974e+05
# 64    1.160805e+06
# 75    1.462126e+06
# 2     2.046107e+05
# 62    1.086712e+06
# 43    6.178477e+05
# 42    5.819769e+05
# 5     2.191170e+05
# 16    2.942080e+05
# 18    2.927886e+05
# ...

# %%
#ypred y_test needs to have their index rearranged.
ypreddf = pd.DataFrame(ypred, columns = ['PIB'])

# %%
ypreddf
# Out:
#              PIB
# 0   3.807224e+05
# 1   1.691863e+06
# 2   2.401722e+05
# 3   8.856339e+05
# 4   1.520744e+06
# 5   1.827850e+06
# 6   2.922018e+05
# 7   1.417550e+06
# 8   8.524715e+05
# 9   1.918013e+06
# 10  8.053220e+05
# 11  1.850886e+06
# 12  1.517026e+06
# 13  2.844727e+05
# 14  2.701086e+05
# 15  4.364409e+05
# 16  3.496773e+05
# 17  3.553372e+05
# 18  4.661432e+05
# 19  2.581188e+05
# 20  6.229255e+05
# 21  1.075761e+06
# 22  2.583203e+05
# 23  1.377809e+06
# 24  6.521792e+05
# 25  7.091195e+05
# 26  2.643322e+05
# 27  1.830272e+06
# 28  1.606410e+06
# 29  1.498813e+06
# 30  1.007654e+06
# 31  1.539686e+06
# 32  1.740458e+06
# 33  1.256439e+06
# 34  7.801995e+05
# 35  3.916190e+05
# 36  3.321179e+05
# 37  8.827427e+05
# 38  1.112291e+06
# 39  1.459577e+06
# 40  2.221262e+05
# 41  1.049950e+06
# 42  5.967801e+05
# 43  5.766845e+05
# 44  2.440732e+05
# 45  3.137561e+05
# 46  3.139022e+05
# 47  5.553377e+05
# 48  5.380125e+05
# 49  2.541657e+05
# 50  1.801185e+06
# ...

# %%
index = y_test.index
ypreddf1 = ypreddf.set_index([pd.Index(index), 'PIB'])

# %%
ypreddf1
# Out:
# Empty DataFrame
# Columns: []
# ...

# %%
ypreddf2 = ypreddf1.sort_index(ascending=True)

# %%
ypreddf2
# Out:
# Empty DataFrame
# Columns: []
# ...

# %%
ypreddf2.values
# Out:
# array([], shape=(60, 0), dtype=float64)

# %%
ypreddf2 = ypreddf2.reset_index(level=['PIB'])
ypreddf2
# Out:
#              PIB
# 1   2.104038e+05
# 2   2.221262e+05
# 3   2.401722e+05
# 4   2.583203e+05
# 5   2.440732e+05
# 6   2.541657e+05
# 7   2.643322e+05
# 8   2.701086e+05
# 9   2.581188e+05
# 12  2.725531e+05
# 14  2.844727e+05
# 16  3.137561e+05
# 17  2.922018e+05
# 18  3.139022e+05
# 19  3.321179e+05
# 23  3.496773e+05
# 24  3.548596e+05
# 25  3.553372e+05
# 27  3.807224e+05
# 28  3.916190e+05
# 29  4.149301e+05
# 31  4.364409e+05
# 34  4.661432e+05
# 35  4.887582e+05
# 36  5.102013e+05
# 39  5.380125e+05
# 41  5.553377e+05
# 42  5.766845e+05
# 43  5.967801e+05
# 44  6.229255e+05
# 46  6.521792e+05
# 49  7.091195e+05
# 51  7.805776e+05
# 52  7.801995e+05
# 53  7.608521e+05
# 54  8.053220e+05
# 55  8.524715e+05
# 56  8.856339e+05
# 57  8.827427e+05
# 60  1.006944e+06
# 61  1.007654e+06
# 62  1.049950e+06
# 63  1.075761e+06
# 64  1.112291e+06
# 69  1.256439e+06
# 72  1.377809e+06
# 74  1.417550e+06
# 75  1.459577e+06
# 76  1.520744e+06
# 77  1.498813e+06
# 79  1.517026e+06
# ...

# %%
ypreddf2.values
# Out:
# array([[ 210403.81468212],
#        [ 222126.18070234],
#        [ 240172.24214266],
#        [ 258320.2558781 ],
#        [ 244073.23497036],
#        [ 254165.74479086],
#        [ 264332.18874223],
#        [ 270108.56430133],
#        [ 258118.76887566],
#        [ 272553.13074204],
#        [ 284472.66093409],
#        [ 313756.13449973],
#        [ 292201.78568364],
#        [ 313902.19023575],
#        [ 332117.91461504],
#        [ 349677.26428262],
#        [ 354859.55612899],
#        [ 355337.19365213],
#        [ 380722.43491463],
#        [ 391619.01119319],
#        [ 414930.07340224],
#        [ 436440.93139642],
#        [ 466143.19648287],
#        [ 488758.19465834],
#        [ 510201.27835607],
#        [ 538012.46869341],
#        [ 555337.66004894],
#        [ 576684.48809526],
#        [ 596780.1355665 ],
#        [ 622925.50711376],
#        [ 652179.22820094],
#        [ 709119.53381459],
#        [ 780577.56255628],
#        [ 780199.53910777],
# ...

# %%
cdfinal2 = cdf2.drop(columns=['Consumo das Famílias', 'Consumo do Governo', 'Formação Bruta de Capital Fixo','Variação de Estoques','Exportação','Importação'])
cdfinal2 = cdfinal2.rename(columns={"Período": "", "PIB": "GDP"})

cdfinal2 = cdfinal2.set_index('')

cdfinal2.info()


cdfinal3 = cdfinal2['GDP'].resample('Q').mean()

# The term bfill means that we use the value before filling in missing values
cdfinal3 = cdfinal3.fillna(cdfinal3.bfill())

cdfinal3

# %%
resultado = cdfinal3

# %%
#now it is ordered


y = resultado

import warnings
import itertools
import pandas as pd
import numpy as np
import statsmodels.api as sm
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')

# Define the p, d and q parameters to take any value between 0 and 2
p = d = q = range(0, 2)

# Generate all different combinations of p, q and q triplets
pdq = list(itertools.product(p, d, q))

# Generate all different combinations of seasonal p, q and q triplets
seasonal_pdq = [(x[0], x[1], x[2], 12) for x in list(itertools.product(p, d, q))]

print('Examples of parameter combinations for Seasonal ARIMA...')
print('SARIMAX: {} x {}'.format(pdq[1], seasonal_pdq[1]))
print('SARIMAX: {} x {}'.format(pdq[1], seasonal_pdq[2]))
print('SARIMAX: {} x {}'.format(pdq[2], seasonal_pdq[3]))
print('SARIMAX: {} x {}'.format(pdq[2], seasonal_pdq[4]))
# Out:
# Examples of parameter combinations for Seasonal ARIMA...
# SARIMAX: (0, 0, 1) x (0, 0, 1, 12)
# SARIMAX: (0, 0, 1) x (0, 1, 0, 12)
# SARIMAX: (0, 1, 0) x (0, 1, 1, 12)
# SARIMAX: (0, 1, 0) x (1, 0, 0, 12)

# %%
warnings.filterwarnings("ignore") # specify to ignore warning messages

for param in pdq:
    for param_seasonal in seasonal_pdq:
        try:
            mod = sm.tsa.statespace.SARIMAX(y,
                                            order=param,
                                            seasonal_order=param_seasonal,
                                            enforce_stationarity=False,
                                            enforce_invertibility=False)

            results = mod.fit()

            print('ARIMA{}x{}12 - AIC:{}'.format(param, param_seasonal, results.aic))
        except:
            continue
# Out:
# ARIMA(0, 0, 0)x(0, 0, 0, 12)12 - AIC:2998.5112692110492
# ARIMA(0, 0, 0)x(0, 0, 1, 12)12 - AIC:2601.6048523671184
# ARIMA(0, 0, 0)x(0, 1, 0, 12)12 - AIC:2375.702995394515
# ARIMA(0, 0, 0)x(0, 1, 1, 12)12 - AIC:2027.3270968513887
# ARIMA(0, 0, 0)x(1, 0, 0, 12)12 - AIC:2255.6405777433542
# ARIMA(0, 0, 0)x(1, 0, 1, 12)12 - AIC:2222.517915868098
# ARIMA(0, 0, 0)x(1, 1, 0, 12)12 - AIC:1917.9748652218166
# ARIMA(0, 0, 0)x(1, 1, 1, 12)12 - AIC:1895.013370317767
# ARIMA(0, 0, 1)x(0, 0, 0, 12)12 - AIC:2903.091738378618
# ARIMA(0, 0, 1)x(0, 0, 1, 12)12 - AIC:2530.453422455885
# ARIMA(0, 0, 1)x(0, 1, 0, 12)12 - AIC:2292.862126253845
# ARIMA(0, 0, 1)x(0, 1, 1, 12)12 - AIC:1962.7474038124017
# ARIMA(0, 0, 1)x(1, 0, 0, 12)12 - AIC:2582.0060865815435
# ARIMA(0, 0, 1)x(1, 0, 1, 12)12 - AIC:2524.743731868685
# ARIMA(0, 0, 1)x(1, 1, 0, 12)12 - AIC:2007.25464379671
# ARIMA(0, 0, 1)x(1, 1, 1, 12)12 - AIC:1955.1782190185982
# ARIMA(0, 1, 0)x(0, 0, 0, 12)12 - AIC:2351.676474939718
# ...

# %%
mod = sm.tsa.statespace.SARIMAX(y,
                                order=(0, 1, 1),
                                seasonal_order=(1, 1, 1, 12),
                                enforce_stationarity=False,
                                enforce_invertibility=False)

results = mod.fit()

print(results.summary().tables[1])
# Out:
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1         -0.2730      0.046     -5.938      0.000      -0.363      -0.183
# ar.S.L12      -0.7218      0.378     -1.910      0.056      -1.462       0.019
# ma.S.L12       0.3663      0.534      0.685      0.493      -0.681       1.414
# sigma2      9.557e+08   3.25e-09   2.94e+17      0.000    9.56e+08    9.56e+08
# ...

# %%
results.plot_diagnostics(figsize=(15, 12))
plt.show()

# %%
pred = results.get_prediction(start=pd.to_datetime('2010-03-31'), dynamic=False)
pred_ci = pred.conf_int()

# %%
ax = y['1996-03-31':].plot(label='observed')
pred.predicted_mean.plot(ax=ax, label='One-step ahead Forecast', alpha=.7)

ax.fill_between(pred_ci.index,
                pred_ci.iloc[:, 0],
                pred_ci.iloc[:, 1], color='k', alpha=.2)

ax.set_xlabel('Date')
ax.set_ylabel('PIB REAL')
plt.legend()

plt.show()

# %%
y_forecasted = pred.predicted_mean
y_truth = y['2005-03-31':]

# Compute the mean square error
mse = ((y_forecasted - y_truth) ** 2).mean()
print('The Mean Squared Error of our forecasts is {}'.format(round(mse, 2)))


pred_dynamic = results.get_prediction(start=pd.to_datetime('2005-03-31'), dynamic=True, full_results=True)
pred_dynamic_ci = pred_dynamic.conf_int()
 

ax = y['1996-03-31':].plot(label='observed', figsize=(20, 15))
pred_dynamic.predicted_mean.plot(label='Dynamic Forecast', ax=ax)

ax.fill_between(pred_dynamic_ci.index,
                pred_dynamic_ci.iloc[:, 0],
                pred_dynamic_ci.iloc[:, 1], color='k', alpha=.25)

ax.fill_betweenx(ax.get_ylim(), pd.to_datetime('2001-01-01'), y.index[-1],
                 alpha=.1, zorder=-1)

ax.set_xlabel('Date')
ax.set_ylabel('PIB REAL')

plt.legend()
plt.show()
# Out:
# The Mean Squared Error of our forecasts is 1448856754.47

# %%
# Extract the predicted and true values of our time series
y_forecasted = pred_dynamic.predicted_mean
y_truth = y['2005-03-31':]

# Compute the mean square error
mse = ((y_forecasted - y_truth) ** 2).mean()
print('The Mean Squared Error of our forecasts is {}'.format(round(mse, 2)))
# Out:
# The Mean Squared Error of our forecasts is 165751785032.09

# %%
# Get forecast 500 steps ahead in future
pred_uc = results.get_forecast(steps=100)

# Get confidence intervals of forecasts
pred_ci = pred_uc.conf_int()

pred_ci.iloc[:, 0]
# Out:
# 2020-12-31    1.862341e+06
# 2021-03-31    1.799992e+06
# 2021-06-30    1.826251e+06
# 2021-09-30    1.846003e+06
# 2021-12-31    1.887836e+06
# 2022-03-31    1.822059e+06
# 2022-06-30    1.875522e+06
# 2022-09-30    1.906311e+06
# 2022-12-31    1.944000e+06
# 2023-03-31    1.865606e+06
# 2023-06-30    1.790844e+06
# 2023-09-30    1.904736e+06
# 2023-12-31    1.934084e+06
# 2024-03-31    1.878349e+06
# 2024-06-30    1.913788e+06
# 2024-09-30    1.935023e+06
# 2024-12-31    1.975960e+06
# 2025-03-31    1.908637e+06
# 2025-06-30    1.964732e+06
# 2025-09-30    2.001030e+06
# 2025-12-31    2.031849e+06
# 2026-03-31    1.945319e+06
# 2026-06-30    1.819639e+06
# 2026-09-30    1.976244e+06
# 2026-12-31    1.986793e+06
# 2027-03-31    1.921763e+06
# 2027-06-30    1.945079e+06
# 2027-09-30    1.959305e+06
# 2027-12-31    1.994751e+06
# 2028-03-31    1.922330e+06
# 2028-06-30    1.970303e+06
# 2028-09-30    1.996435e+06
# 2028-12-31    2.026081e+06
# 2029-03-31    1.939361e+06
# ...

# %%
 ax = y.plot(label='observed', figsize=(20, 15))
pred_uc.predicted_mean.plot(ax=ax, label='Forecast')
ax.fill_between(pred_ci.index,
                pred_ci.iloc[:, 0],
                pred_ci.iloc[:, 1], color='k', alpha=.25)
ax.set_xlabel('Date')
ax.set_ylabel('PIB REAL')

plt.legend()
plt.show()
